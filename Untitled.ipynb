# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_html('https://f1.fandom.com/wiki/Circuits')

# %%
df[0]
# Out:
#                        Circuit     Type          Location Country  \
# 0                      A1-Ring     race           Zeltweg     AUT
# 1      Adelaide Street Circuit   street          Adelaide     AUS
# 2                     Ain-Diab     road        Casablanca     MAR
# 3                      Aintree     race           Aintree     GBR
# 4                  Albert Park   street         Melbourne     AUS
# ..                         ...      ...               ...     ...
# 91  Watkins Glen International     race  Watkins Glen, NY     USA
# 92          Yas Marina Circuit     race         Abu Dhabi     UAE
# 93      Circuit Park Zandvoort     race         Zandvoort     NED
# 94            Zeltweg Airfield  airport           Zeltweg     AUT
# 95              Circuit Zolder     race    Heusden-Zolder     BEL
#
#              Race(s)                                          Season(s)  \
# 0        Austrian GP                                          1997-2003
# ...
